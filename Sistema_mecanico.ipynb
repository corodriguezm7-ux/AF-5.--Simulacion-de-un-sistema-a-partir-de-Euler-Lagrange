# %% [markdown]
# <a href="https://colab.research.google.com/github/corodriguezm7-ux/AF-5.--Simulacion-de-un-sistema-a-partir-de-Euler-Lagrange/blob/main/Sistema_mecanico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
